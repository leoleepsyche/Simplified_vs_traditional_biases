# %%
import pandas as pd

# Login using e.g. `huggingface-cli login` to access this dataset
splits = {'ar': 'by_language/ar.csv', 'bn': 'by_language/bn.csv', 'de': 'by_language/de.csv', 'en': 'by_language/en.csv', 'es': 'by_language/es.csv', 'fr': 'by_language/fr.csv', 'hi': 'by_language/hi.csv', 'it': 'by_language/it.csv', 'mr': 'by_language/mr.csv', 'nl': 'by_language/nl.csv', 'pl': 'by_language/pl.csv', 'pt_br': 'by_language/pt_br.csv', 'ro': 'by_language/ro.csv', 'ru': 'by_language/ru.csv', 'zh': 'by_language/zh.csv', 'zh_hant': 'by_language/zh_hant.csv'}
zh_path = "hf://datasets/LanguageShades/BiasShades/" + splits["zh"]
zh_hant_path = "hf://datasets/LanguageShades/BiasShades/" + splits["zh_hant"]
en_path = "hf://datasets/LanguageShades/BiasShades/" + splits["en"]
df_zh = pd.read_csv(zh_path)
df_zh_hant = pd.read_csv(zh_hant_path)
df_en = pd.read_csv(en_path)

# %%
df_zh
# Out:
#      index     subset   bias_type stereotype_origin_langs  \
# 0      1.0  _original  ['gender']                  ['fr']
# 1      1.0          a  ['gender']                      []
# 2      2.0  _original  ['gender']            ['fr', 'ro']
# 3      2.0          a  ['gender']                      []
# 4      3.0  _original  ['gender']                  ['fr']
# ..     ...        ...         ...                     ...
# 723  280.0          a  ['gender']                      []
# 724  281.0  _original  ['gender']                  ['de']
# 725  281.0          a  ['gender']                      []
# 726  282.0  _original     ['age']                  ['zh']
# 727  282.0          a     ['age']                      []
#
#                                 stereotype_valid_langs  \
# 0    ['ar', 'bn', 'de', 'en', 'fr', 'hi', 'it', 'mr...
# 1                                                   []
# 2    ['ar', 'bn', 'en', 'fr', 'hi', 'it', 'mr', 'nl...
# ...

# %%
df_zh_hant
# Out:
#      index     subset   bias_type stereotype_origin_langs  \
# 0      1.0  _original  ['gender']                  ['fr']
# 1      1.0          a  ['gender']                      []
# 2      2.0  _original  ['gender']            ['fr', 'ro']
# 3      2.0          a  ['gender']                      []
# 4      3.0  _original  ['gender']                  ['fr']
# ..     ...        ...         ...                     ...
# 723  280.0          a  ['gender']                      []
# 724  281.0  _original  ['gender']                  ['de']
# 725  281.0          a  ['gender']                      []
# 726  282.0  _original     ['age']                  ['zh']
# 727  282.0          a     ['age']                      []
#
#                                 stereotype_valid_langs  \
# 0    ['ar', 'bn', 'de', 'en', 'fr', 'hi', 'it', 'mr...
# 1                                                   []
# 2    ['ar', 'bn', 'en', 'fr', 'hi', 'it', 'mr', 'nl...
# ...

# %%
df_en
# Out:
#      index     subset   bias_type stereotype_origin_langs  \
# 0      1.0  _original  ['gender']                  ['fr']
# 1      1.0          a  ['gender']                      []
# 2      2.0  _original  ['gender']            ['fr', 'ro']
# 3      2.0          a  ['gender']                      []
# 4      3.0  _original  ['gender']                  ['fr']
# ..     ...        ...         ...                     ...
# 723  280.0          a  ['gender']                      []
# 724  281.0  _original  ['gender']                  ['de']
# 725  281.0          a  ['gender']                      []
# 726  282.0  _original     ['age']                  ['zh']
# 727  282.0          a     ['age']                      []
#
#                                 stereotype_valid_langs  \
# 0    ['ar', 'bn', 'de', 'en', 'fr', 'hi', 'it', 'mr...
# 1                                                   []
# 2    ['ar', 'bn', 'en', 'fr', 'hi', 'it', 'mr', 'nl...
# ...
